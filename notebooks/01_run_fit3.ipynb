# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..") / "src"))

# %%
from run_fit import run

n_components = 3

x_final, summary = run("../configs/fit3_config.json", n_components=n_components)

summary
# Out:
# {'run_timestamp': '2026-03-31_14-20-00',
#  'config_path': '../configs/fit3_config.json',
#  'n_components': 3,
#  'stage1_success': True,
#  'stage1_cost': 0.02724764871126705,
#  'stage2_success': True,
#  'stage2_cost': 0.02480873441876697,
#  'T_shape': [41],
#  'V_prime_shape': [3, 41],
#  'U_prime_shape': [221, 3],
#  'spectral_matrix_shape': [221, 41],
#  'wavelengths_shape': [221],
#  'preprocess_coeffs': {'C11': 0.17914457270243378,
#   'C21': -0.06334541521769797,
#   'C31': 0.3344922692393428,
#   'C13': 0.012580350421504778,
#   'C23': 0.4042360826666315,
#   'C33': 0.17439882620973818},
#  'output_dir': '../results/fit3_run/fit3_2026-03-31_14-20-00',
#  'final_params': {'Tm1': 324.2133822380313,
#   'Tm2': 359.1830528914419,
#   'dH1': -13052.26845378919,
#   'dH2': -58145.860497129834,
#   'C11': 0.1807800854132836,
#   'C12': 0.17361535147139187,
#   'C13': 0.003099600079883927,
#   'C21': -0.06670430352736927,
#   'C22': 0.01139134215245286,
# ...

# %%
from IPython.display import Image, display, Markdown
from pathlib import Path

out_dir = Path(summary["output_dir"])

display(Markdown("## Preprocessing - Folded spectrum"))
display(Image(filename=str(out_dir / "preprocess_folded_fit.png")))

display(Markdown("## Preprocessing - Unfolded spectrum"))
display(Image(filename=str(out_dir / "preprocess_unfolded_fit.png")))

display(Markdown("## Stage 1 global fit"))
display(Image(filename=str(out_dir / "stage1_global_fit.png")))

display(Markdown("## Final global fit"))
display(Image(filename=str(out_dir / "final_global_fit.png")))
# Out:
# ## Preprocessing - Folded spectrum
# ## Preprocessing - Unfolded spectrum
# ## Stage 1 global fit
# ## Final global fit

# %%
import pandas as pd
from pathlib import Path

out_dir = Path(summary["output_dir"])

df_stage1 = pd.read_csv(out_dir / "stage1_fit_curves.csv")
df_final = pd.read_csv(out_dir / "final_fit_curves.csv")

df_stage1.head(), df_final.head()
# Out:
# (   T_kelvin  T_celsius    V1_exp    V1_fit  V1_resid    V2_exp    V2_fit  \
#  0    293.15       20.0  0.179252  0.178486  0.000766 -0.056982 -0.055229
#  1    295.15       22.0  0.178832  0.178391  0.000441 -0.068574 -0.054058
#  2    297.15       24.0  0.178924  0.178286  0.000638 -0.071405 -0.052762
#  3    299.15       26.0  0.178446  0.178171  0.000275 -0.057626 -0.051337
#  4    301.15       28.0  0.178620  0.178044  0.000576 -0.069443 -0.049781
#
#     V2_resid    V3_exp    V3_fit  V3_resid
#  0 -0.001752  0.332520  0.259690  0.072829
#  1 -0.014516  0.261007  0.248893  0.012114
#  2 -0.018643  0.236864  0.236948 -0.000083
#  3 -0.006289  0.255741  0.223817  0.031925
#  4 -0.019662  0.232103  0.209479  0.022624  ,
#     T_kelvin  T_celsius    V1_exp    V1_fit  V1_resid    V2_exp    V2_fit  \
#  0    293.15       20.0  0.179252  0.180031 -0.000778 -0.056982 -0.058534
#  1    295.15       22.0  0.178832  0.179922 -0.001091 -0.068574 -0.057355
# ...
